# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
working_dir = f'/projects/eb7fd651-8ca7-45f4-8470-34087f434ad6/Code/Final_Build/0_deg/15_0'

raw_profiles_path = f"{working_dir}/15_0_km_s_0_0_rad_0_25_b_6_pts_noise_raw_profiles.npy"
oot_profile_path = f"{working_dir}/15_0_km_s_0_0_rad_0_25_b_6_pts_noise_oot_profile.npy"

raw_profiles = np.load(raw_profiles_path)
oot_profile = np.load(oot_profile_path)

coordinates = np.load(coordinates_path)

# %%
figsize=(15,15)
titlesize=40
linewidth=3
ticksize=28
labelsize=34

# %%
plt.figure(figsize=figsize)
plt.title("OOT Profile", fontsize=titlesize)
plt.plot(oot_profile, 'r', linewidth=linewidth)
plt.xlabel("Bin Number", fontsize=labelsize)
plt.ylabel("Relative Intensity", fontsize=labelsize)
plt.xticks(fontsize=ticksize)
plt.yticks(fontsize=ticksize)
plt.show()

# %%
raw=raw_profiles[5]

plt.figure(figsize=figsize)
plt.title("Sample In-Transit Profile", fontsize=titlesize)
plt.plot(raw, 'b', linewidth=linewidth)
plt.xlabel("Bin Number", fontsize=labelsize)
plt.ylabel("Relative Intensity", fontsize=labelsize)
plt.xticks(fontsize=ticksize)
plt.yticks(fontsize=ticksize)
plt.show()

# %%
residual=raw-oot_profile

plt.figure(figsize=figsize)
plt.title("Sample In-Transit Profile", fontsize=titlesize)
plt.plot(residual, 'purple', linewidth=linewidth)
plt.xlabel("Bin Number", fontsize=labelsize)
plt.ylabel("Relative Intensity", fontsize=labelsize)
plt.xticks(fontsize=ticksize)
plt.yticks(fontsize=ticksize)
plt.show()
